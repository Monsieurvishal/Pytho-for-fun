# %%
#python Code to generate qr code
import pyqrcode
import png
from pyqrcode import QRCode
url='https://iotand5g.blogspot.com/'
url=pyqrcode.create(url)
url.png('qr.png',scale=8)

# %%
#python code to take screenshot
import pyautogui
pyautogui.screenshot(r"E:\python\screen.png")
# Out:
# <PIL.Image.Image image mode=RGB size=1920x1080 at 0x1D863B00BE0>

# %%
from tqdm import tqdm
from time import sleep
for i in tqdm(range(20)):
    sleep(1)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 20/20 [00:20<00:00,  1.01s/it]
